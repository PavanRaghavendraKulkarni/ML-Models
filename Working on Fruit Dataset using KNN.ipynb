# %%
# %matplotlib notebook
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
df=pd.read_table("fruit_data_with_colors.txt")

# %%
df.head()
# Out:
#    fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 0            1      apple  granny_smith   192    8.4     7.3         0.55
# 1            1      apple  granny_smith   180    8.0     6.8         0.59
# 2            1      apple  granny_smith   176    7.4     7.2         0.60
# 3            2   mandarin      mandarin    86    6.2     4.7         0.80
# 4            2   mandarin      mandarin    84    6.0     4.6         0.79

# %%
df.shape
# Out:
# (59, 7)

# %%
x=df[["mass","width","height"]]
y=df[["color_score"]]
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=0)

# %%
print(x_train.shape)
print(y_train.head())
print(x_test.shape)
print(y_test.head())
# Out:
# (44, 3)
#     color_score
# 42         0.82
# 48         0.72
# 7          0.81
# 14         0.69
# 32         0.80
# (15, 3)
#     color_score
# 26         0.74
# 35         0.75
# 43         0.70
# 28         0.72
# 11         0.92

# %%
df
# Out:
#     fruit_label fruit_name     fruit_subtype  mass  width  height  color_score
# 0             1      apple      granny_smith   192    8.4     7.3         0.55
# 1             1      apple      granny_smith   180    8.0     6.8         0.59
# 2             1      apple      granny_smith   176    7.4     7.2         0.60
# 3             2   mandarin          mandarin    86    6.2     4.7         0.80
# 4             2   mandarin          mandarin    84    6.0     4.6         0.79
# 5             2   mandarin          mandarin    80    5.8     4.3         0.77
# 6             2   mandarin          mandarin    80    5.9     4.3         0.81
# 7             2   mandarin          mandarin    76    5.8     4.0         0.81
# 8             1      apple          braeburn   178    7.1     7.8         0.92
# 9             1      apple          braeburn   172    7.4     7.0         0.89
# 10            1      apple          braeburn   166    6.9     7.3         0.93
# ...

# %%
fruit_name=dict(zip((df.fruit_label.unique()),(df.fruit_name.unique())))

# %%
sns.scatterplot(x="height",y="width",hue="fruit_label",data=df)
# Out:
# <div id='4b07a7dc-3f46-455c-a9fa-4f8cf7629094'></div>

# %%
x=df[["mass","width","height"]]
y=df["fruit_label"]
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=0)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier(n_neighbors=10)

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
knn.score(x_test,y_test)
# Out:
# 0.3333333333333333

# %%
y=knn.predict([[100,6.3,8.5]])
print(fruit_name[y[0]])
# Out:
# lemon

# %%
y=knn.predict([[20,6.3,8.5]])
print(fruit_name[y[0]])
# Out:
# lemon

# %%
y=knn.predict([[362,9.6,9.2]])
print(fruit_name[y[0]])
# Out:
# orange

# %%
from adspy_shared_utilities.py import plot_fruit_knn
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-25-7929d548f4ab> in <module>
# ----> 1 from adspy_shared_utilities.py import plot_fruit_knn
#
# ModuleNotFoundError: No module named 'adspy_shared_utilities'
